# %% [markdown]
# # Importar librerias

# %%
# pip install matplotlib
# pip install matplotlib
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
print(matplotlib.__version__)
# Out:
# 3.8.3

# %%
df = sns.load_dataset('titanic').dropna(subset=['age', 'fare', 'survived'])
tips = sns.load_dataset('tips')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Tipos de gráficos

# %% [markdown]
# ## Gráfico de líneas
#
# Variables temporales o secuenciales (series de tiempo).
#
# Relaciones entre dos variables continuas.

# %%
edad_media_clase = df.groupby('class',observed=True)['age'].mean()
plt.figure(figsize=(10, 5))
ax = plt.subplot(111)
plt.plot(edad_media_clase.index, edad_media_clase.values, marker='o', linestyle='--', color='r')
plt.title('Edad media por clase')
plt.xlabel('Clase de cabina')
plt.ylabel('Edad media')
plt.grid(True)
plt.show()

# %%
edad_media_clase = df.groupby('class', observed=True)['age'].mean()
ax = edad_media_clase.plot(marker='o', linestyle='--', color='r', figsize=(10, 5), title='Edad media por clase')
ax.set_xlabel('Clase de cabina')
ax.set_ylabel('Edad media')
ax.grid(True)
plt.show()

# %%
tarifa_promedio = df.groupby('class', observed=True)['fare'].mean()
plt.figure(figsize=(8, 6))
ax = plt.subplot(111)
plt.grid(True)
font_title = {'family': 'monospace', 'color': 'darkred', 'size': 20}
plt.title('Tarifa/Clase', fontdict=font_title, loc='center', pad=10)
font_label = {'family': 'fantasy', 'color': 'teal', 'size': 15}
plt.xlabel('Clase', fontdict=font_label)
plt.ylabel('Tarifa Promedio ($)', fontdict=font_label)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.plot(tarifa_promedio.index,tarifa_promedio, marker='o', color='navy', ls='dotted', lw=2, mec='red', mfc='yellow', markersize=8)
plt.legend(["Tarifa Promedio"])
plt.show()

# %%
tarifa_promedio = df.groupby('class', observed=True)['fare'].mean()
ax = tarifa_promedio.plot(marker='o', color='navy', ls='dotted', lw=2, mec='red', mfc='yellow', markersize=8, figsize=(8, 6), grid=True, legend=True)
ax.set_title('Tarifa/Clase', fontdict={'family': 'monospace', 'color': 'darkred', 'size': 20}, loc='center', pad=10)
ax.set_xlabel('Clase', fontdict={'family': 'fantasy', 'color': 'teal', 'size': 15})
ax.set_ylabel('Tarifa Promedio ($)', fontdict={'family': 'fantasy', 'color': 'teal', 'size': 15})
ax.grid(color='gray', linestyle='--', linewidth=0.5)
plt.show()

# %%
tarifa_promedio = df.groupby('embark_town', observed=True)['fare'].mean()

plt.figure(figsize=(10, 6))
ax = plt.subplot(111) 
ax.set_facecolor('whitesmoke')  
plt.grid(True, color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
font_title = {'family': 'Arial', 'color': 'darkblue', 'size': 20, 'weight': 'bold'}
plt.title('Tarifa/Ciudad de Embarque', fontdict=font_title, loc='center', pad=20)
font_label = {'family': 'Arial', 'color': 'darkslategray', 'size': 15, 'weight': 'bold'}
plt.xlabel('Ciudad de Embarque', fontdict=font_label)
plt.ylabel('Tarifa Promedio ($)', fontdict=font_label)
plt.plot(tarifa_promedio.index,tarifa_promedio, marker='o', color='royalblue', ls='-', lw=2, mec='crimson', mfc='lightblue', markersize=10)
plt.legend(["Tarifa Promedio"], frameon=True, framealpha=0.8, facecolor='lightgrey', edgecolor='black')
plt.xticks(rotation=45) 
ax.spines['top'].set_visible(False)  
ax.spines['right'].set_visible(False)  
plt.show()

# %%
tarifa_promedio = df.groupby('embark_town', observed=True)['fare'].mean()
ax = tarifa_promedio.plot(marker='o', color='royalblue', ls='-', lw=2, mec='crimson', mfc='lightblue', markersize=10, figsize=(10, 6), grid=True, legend=True, rot=45)
ax.set_facecolor('whitesmoke')
ax.set_title('Tarifa/Ciudad de Embarque', fontdict={'family': 'Arial', 'color': 'darkblue', 'size': 20, 'weight': 'bold'}, loc='center', pad=20)
ax.set_xlabel('Ciudad de Embarque', fontdict={'family': 'Arial', 'color': 'darkslategray', 'size': 15, 'weight': 'bold'})
ax.set_ylabel('Tarifa Promedio ($)', fontdict={'family': 'Arial', 'color': 'darkslategray', 'size': 15, 'weight': 'bold'})
ax.grid(True, color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# ## Gráfico de Barras
#
# Variables categóricas o discretas en el eje x.
#
# Comparaciones entre diferentes categorías.
#
# Frecuencia o recuento de categorías.

# %%
pasajeros_por_clase = df['class'].value_counts()
ax = plt.subplot(111)
plt.bar(pasajeros_por_clase.index, pasajeros_por_clase, color='c')
plt.title('Número de Pasajeros por Clase')
plt.xlabel('Clase')
plt.ylabel('Número de Pasajeros')
plt.show()

# %%
pasajeros_por_clase = df['class'].value_counts()
ax = pasajeros_por_clase.plot(kind='bar', color='c', figsize=(8, 5), title='Número de Pasajeros por Clase')
ax.set_xlabel('Clase')
ax.set_ylabel('Número de Pasajeros')
plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = plt.subplot(111)
plt.bar(pasajeros_por_clase.index, pasajeros_por_clase, color=['skyblue', 'salmon', 'lightgreen'], width=0.8, alpha=0.9)
ax.set_facecolor('whitesmoke')
ax.set_title('Número de Pasajeros por Clase', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Clase', fontsize=14, color='darkgreen')
ax.set_ylabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xticks(rotation=0, fontsize=12)
plt.show()

# %%
ax = pasajeros_por_clase.plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen'], width=0.8, alpha=0.9, figsize=(8, 5))
ax.set_facecolor('whitesmoke')
ax.set_title('Número de Pasajeros por Clase', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Clase', fontsize=14, color='darkgreen')
ax.set_ylabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=12)
plt.show()

# %%
supervivientes_por_sexo = df.pivot_table(index='sex', columns='survived', aggfunc='size')
plt.figure(figsize=(8, 5))
ax = plt.subplot(111)
supervivientes_por_sexo.plot(kind='bar', stacked=True, color=['#98FB98','#66b3ff'], ax=ax)
ax.set_facecolor('whitesmoke')
ax.set_title('Número de Supervivientes por Sexo', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Sexo', fontsize=14, color='darkgreen')
ax.set_ylabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(["No Sobrevivieron", "Sobrevivieron"], title="Estado", title_fontsize='13')

plt.xticks(rotation=0, fontsize=12)
plt.show()

# %%
pasajeros_por_puerto = df['embark_town'].value_counts()
plt.figure(figsize=(8, 5))
ax = plt.subplot(111)

plt.bar(pasajeros_por_puerto.index,pasajeros_por_puerto, color=['plum', 'lightblue', 'peachpuff'])
ax.set_facecolor('whitesmoke')
ax.set_title('Número de Pasajeros por Puerto de Embarque', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Puerto de Embarque', fontsize=14, color='darkgreen')
ax.set_ylabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xticks(rotation=0, fontsize=12)
plt.show()

# %%
pasajeros_por_puerto = df['embark_town'].value_counts()
ax = pasajeros_por_puerto.plot(kind='bar', color=['plum', 'lightblue', 'peachpuff'], figsize=(8, 5))
ax.set_facecolor('whitesmoke')
ax.set_title('Número de Pasajeros por Puerto de Embarque', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Puerto de Embarque', fontsize=14, color='darkgreen')
ax.set_ylabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=12)
plt.show()

# %% [markdown]
# ## Gráfico de Barras Horizontales
#
# Similar al gráfico de barras, pero más adecuado cuando tienes muchas categorías o cuando quieres que las etiquetas del eje x sean más legibles

# %%
pasajeros_sexo = df['sex'].value_counts()
plt.figure(figsize=(10, 5))
ax = plt.subplot(111)
plt.barh(pasajeros_sexo.index, pasajeros_sexo.values, color='c')
plt.title('Número de pasajeros por sexo')
plt.xlabel('Número de pasajeros')
plt.ylabel('Sexo')
plt.show()

# %%
pasajeros_sexo = df['sex'].value_counts()
ax = pasajeros_sexo.plot(kind='barh', color='c', figsize=(10, 5), title='Número de pasajeros por sexo')
ax.set_xlabel('Número de pasajeros')
ax.set_ylabel('Sexo')
plt.show()

# %%
supervivientes_por_sexo = df.pivot_table(index='sex', columns='survived', aggfunc='size')
categorias = supervivientes_por_sexo.index
no_sobrevivieron = supervivientes_por_sexo[0]  
sobrevivieron = supervivientes_por_sexo[1]     

y = np.arange(len(categorias))

plt.figure(figsize=(10, 5))
ax = plt.subplot(111)

plt.barh(y, no_sobrevivieron, color='black', label='No Sobrevivieron')
plt.barh(y, sobrevivieron, left=no_sobrevivieron, color='#66b3ff', label='Sobrevivieron')

ax.set_facecolor('whitesmoke')
ax.set_title('Supervivientes por Sexo en el Titanic', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.set_ylabel('Sexo', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks(y)
ax.set_yticklabels(categorias)
ax.legend(title="Estado", title_fontsize='13')

plt.show()

# %%
supervivientes_por_sexo = df.pivot_table(index='sex', columns='survived', aggfunc='size')
supervivientes_por_sexo.plot(kind='barh', stacked=True, color=['black', '#66b3ff'], figsize=(10, 5))
ax = plt.gca()
ax.set_facecolor('whitesmoke')
ax.set_title('Supervivientes por Sexo en el Titanic', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Número de Pasajeros', fontsize=14, color='darkgreen')
ax.set_ylabel('Sexo', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle=':', linewidth=0.5, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(['No Sobrevivieron', 'Sobrevivieron'], title="Estado", title_fontsize='13')
plt.show()

# %% [markdown]
# ## Histograma
#
# Variables numéricas continuas.
#
# Distribuciones de frecuencia de una sola variable.
#
# Identificar la forma y distribución de los datos.

# %%
plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
plt.hist(df['age'], bins=20, color='steelblue', edgecolor='black', alpha=0.7)
plt.title('Distribución de las edades de los pasajeros')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %%
ax = df['age'].plot(kind='hist', bins=20, color='steelblue', edgecolor='black', alpha=0.7, figsize=(10, 6), title='Distribución de las edades de los pasajeros')
ax.set_xlabel('Edad')
ax.set_ylabel('Frecuencia')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['fare'], bins=20, color='darkred', alpha=0.7)
font_title = {'family': 'monospace', 'color':'black','size':15}
plt.title("Distribución de la tarifa pagada por los pasajeros", fontdict = font_title, loc = 'center', pad=10)
font_label = {'family': 'fantasy', 'color':'teal','size':15}
plt.xlabel('Tarifa',  fontdict=font_label)
plt.ylabel('Frecuencia', fontdict=font_label)
plt.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %%
ax = df['fare'].plot(kind='hist', bins=20, color='darkred', alpha=0.7, figsize=(10, 5), title="Distribución de la tarifa pagada por los pasajeros")
ax.set_xlabel('Tarifa')
ax.set_ylabel('Frecuencia')
ax.title.set_fontsize(15)
ax.title.set_color('black')
ax.xaxis.label.set_color('teal')
ax.xaxis.label.set_fontsize(15)
ax.xaxis.label.set_fontstyle('italic')
ax.yaxis.label.set_color('teal')
ax.yaxis.label.set_fontsize(15)
ax.yaxis.label.set_fontstyle('italic')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %% [markdown]
# ## Gráfico de Dispersión (Scatter Plot)
#
# Relaciones entre dos variables continuas.
#
# Identificar patrones o tendencias.
#
# Detectar la presencia de valores atípicos o anomalías.

# %%
plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
plt.scatter(df['age'], df['fare'], alpha=0.7, color='darkred', edgecolor='black')
ax.set_facecolor('whitesmoke')
ax.set_title('Relación entre Edad y Tarifa en el Titanic', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Edad', fontsize=14, color='darkgreen')
ax.set_ylabel('Tarifa', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %%
ax = df.plot(kind='scatter', x='age', y='fare', color='darkred', edgecolor='black', alpha=0.7, figsize=(10, 6), title='Relación entre Edad y Tarifa en el Titanic')
ax.set_facecolor('whitesmoke')
ax.set_xlabel('Edad', fontsize=14, color='darkgreen')
ax.set_ylabel('Tarifa', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
class_map = {'First': 1, 'Second': 2, 'Third': 3}
df['class_numeric'] = df['class'].map(class_map)
plt.scatter(df['class_numeric'], df['fare'], alpha=0.7, color='gold', edgecolor='black')
ax.set_facecolor('whitesmoke')
ax.set_title('Relación entre Clase y Tarifa en el Titanic', fontsize=16, color='darkblue', weight='bold')
ax.set_xlabel('Clase', fontsize=14, color='darkgreen')
ax.set_ylabel('Tarifa', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['Primera', 'Segunda', 'Tercera'])

plt.show()

# %%
ax = df.plot(kind='scatter', x='class', y='fare', color='gold', edgecolor='black', alpha=0.7, figsize=(10, 6), title='Relación entre Clase y Tarifa en el Titanic')
ax.set_facecolor('whitesmoke')
ax.set_xlabel('Clase', fontsize=14, color='darkgreen')
ax.set_ylabel('Tarifa', fontsize=14, color='darkgreen')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['Primera', 'Segunda', 'Tercera'])
plt.show()

# %% [markdown]
# ## Gráfico de Caja (Box Plot)
#
# Variables numéricas.
#
# Comparar distribuciones de una o más variables.
#
# Identificar valores atípicos, dispersión y simetría en los datos.

# %%
plt.figure(figsize=(8, 6))
data_to_plot = df.groupby('class', observed=True)['fare'].apply(list)
plt.boxplot(data_to_plot, labels=data_to_plot.index)
font_title = {'family': 'monospace', 'color':'darkblue','size':15}
font_label = {'family': 'fantasy', 'color':'teal','size':15}
plt.title('Distribución de Tarifas por Clase en el Titanic',fontdict=font_title)
plt.xlabel('Clase',fontdict=font_label)
plt.ylabel('Tarifa',fontdict=font_label)
plt.show()

# %%
ax = df.boxplot(column='fare', by='class', figsize=(8, 6))
ax.set_title('Distribución de Tarifas por Clase en el Titanic')
ax.figure.suptitle('')
ax.set_xlabel('Clase')
ax.set_ylabel('Tarifa')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
ax.title.set_fontsize(15)
ax.title.set_color('darkblue')
ax.xaxis.label.set_fontsize(15)
ax.xaxis.label.set_color('teal')
ax.yaxis.label.set_fontsize(15)
ax.yaxis.label.set_color('teal')
plt.show()

# %%
plt.figure(figsize=(8, 6))
data_to_plot = df.groupby('sex', observed=True)['fare'].apply(list)
plt.boxplot(data_to_plot, labels=data_to_plot.index)
font_title = {'family': 'monospace', 'color':'darkblue','size':15}
font_label = {'family': 'fantasy', 'color':'teal','size':15}
plt.title('Distribución de Tarifas por Clase en el Titanic',fontdict=font_title)
plt.xlabel('Clase',fontdict=font_label)
plt.ylabel('Tarifa',fontdict=font_label)
plt.show()

# %%
ax = df.boxplot(column='fare', by='sex', figsize=(8, 6))
ax.set_title('Distribución de Tarifas por Sexo en el Titanic')
ax.figure.suptitle('')
ax.set_xlabel('Sexo')
ax.set_ylabel('Tarifa')
ax.grid(color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
ax.title.set_fontsize(15)
ax.title.set_color('darkblue')
ax.xaxis.label.set_fontsize(15)
ax.xaxis.label.set_color('teal')
ax.yaxis.label.set_fontsize(15)
ax.yaxis.label.set_color('teal')
plt.show()

# %% [markdown]
# ## Gráfico Circular (Pie Chart)
#
# Variables categóricas.
#
# Mostrar la proporción de cada categoría en un conjunto de datos.

# %%
pasajeros_por_clase = df['class'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(pasajeros_por_clase, labels=pasajeros_por_clase.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999', '#99ff99', '#9999ff'])
plt.title('Proporción de Pasajeros por Clase', fontsize=16, color='darkblue')
plt.ylabel('') 
plt.show()

# %%
pasajeros_por_clase = df['class'].value_counts()
ax = pasajeros_por_clase.plot(kind='pie', figsize=(8, 6), autopct='%1.1f%%', startangle=90, colors=['#ff9999', '#99ff99', '#9999ff'], title='Proporción de Pasajeros por Clase')
ax.set_ylabel('')  
plt.show()

# %%
supervivientes_por_sexo = df.groupby('sex')['survived'].sum()
plt.figure(figsize=(8, 6))
plt.pie(supervivientes_por_sexo, labels=supervivientes_por_sexo.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff6666'])
plt.title('Proporción de Supervivientes por Sexo', fontsize=16, color='darkblue')
plt.ylabel('')
plt.show()

# %%
supervivientes_por_sexo = df.groupby('sex')['survived'].sum()
ax = supervivientes_por_sexo.plot(kind='pie', figsize=(8, 6), autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff6666'], title='Proporción de Supervivientes por Sexo')
ax.set_ylabel('')
plt.show()

# %%
pasajeros_por_puerto = df['embark_town'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(pasajeros_por_puerto, labels=pasajeros_por_puerto.index, autopct='%1.1f%%', startangle=90, colors=['#ffcc99', '#99ff99', '#ff9999'])
plt.title('Distribución de Pasajeros por Puerto de Embarque', fontsize=16, color='darkblue')
plt.ylabel('')
plt.show()

# %%
pasajeros_por_puerto = df['embark_town'].value_counts()
ax = pasajeros_por_puerto.plot(kind='pie', figsize=(8, 6), autopct='%1.1f%%', startangle=90, colors=['#ffcc99', '#99ff99', '#ff9999'], title='Distribución de Pasajeros por Puerto de Embarque')
ax.set_ylabel('')
plt.show()
